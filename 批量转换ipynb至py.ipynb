# %%
def getExtfileList(filepath, extensionName):
    """获取指定文件后缀名的所有文件列表"""
    # 后缀名中不允许有"."
    filelists = []
    for eachfilePath, d, filelist in os.walk(filepath):
        for eachfilename in filelist:
            if eachfilename.split(".")[-1].lower() == extensionName.lower():
                tempfile = os.path.join(eachfilePath, eachfilename)
                filelists.append(tempfile)
    return filelists


def ipynb_to_py(ipynb_file, py_ext='.py'):
    py_file = os.path.splitext(ipynb_file)[0] + py_ext
    if os.path.exists(py_file):
        return None
    command = 'jupyter nbconvert --to script %s' % (ipynb_file, )
    os.system(command)

import os
if __name__ == '__main__':
    # 这里填写要转换文件夹目录
    filepath = os.getcwd()
    extensionName = 'ipynb'
    ipynb_file_list = getExtfileList(filepath, extensionName)
    file_count = len(ipynb_file_list)
    for index, ipynb_file in enumerate(ipynb_file_list):
        print('正在转换第%s/%s个文件:%s' % (index + 1, file_count, ipynb_file))
        ipynb_to_py(ipynb_file)
    print('全部.ipynb文件转换完成！')
# Out:
# 正在转换第1/65个文件:C:\Users\Li\python\41904516李润杨大作业.ipynb
# 正在转换第2/65个文件:C:\Users\Li\python\CVCheck.ipynb
# 正在转换第3/65个文件:C:\Users\Li\python\DataFrame.ipynb
# 正在转换第4/65个文件:C:\Users\Li\python\Excel文件操作.ipynb
# 正在转换第5/65个文件:C:\Users\Li\python\jieba.ipynb
# 正在转换第6/65个文件:C:\Users\Li\python\JupyterNotebook的使用——以函数为例.ipynb
# 正在转换第7/65个文件:C:\Users\Li\python\Matplotlib.ipynb
# 正在转换第8/65个文件:C:\Users\Li\python\modulepkg.ipynb
# 正在转换第9/65个文件:C:\Users\Li\python\Openpyxl.ipynb
# 正在转换第10/65个文件:C:\Users\Li\python\SQL.ipynb
# 正在转换第11/65个文件:C:\Users\Li\python\七律诗排版.ipynb
# 正在转换第12/65个文件:C:\Users\Li\python\中美货币转换.ipynb
# 正在转换第13/65个文件:C:\Users\Li\python\之家签到.ipynb
# 正在转换第14/65个文件:C:\Users\Li\python\五角星数.ipynb
# 正在转换第15/65个文件:C:\Users\Li\python\分号合并.ipynb
# 正在转换第16/65个文件:C:\Users\Li\python\列表推导式学生姓名.ipynb
# 正在转换第17/65个文件:C:\Users\Li\python\去除n.ipynb
# 正在转换第18/65个文件:C:\Users\Li\python\反相关.ipynb
# 正在转换第19/65个文件:C:\Users\Li\python\句子词数.ipynb
# 正在转换第20/65个文件:C:\Users\Li\python\句子重组.ipynb
# 正在转换第21/65个文件:C:\Users\Li\python\四叶玫瑰数.ipynb
# 正在转换第22/65个文件:C:\Users\Li\python\定积分.ipynb
# 正在转换第23/65个文件:C:\Users\Li\python\密码.ipynb
# 正在转换第24/65个文件:C:\Users\Li\python\帕多瓦数列.ipynb
# 正在转换第25/65个文件:C:\Users\Li\python\异常.ipynb
# 正在转换第26/65个文件:C:\Users\Li\python\打印汉字.ipynb
# 正在转换第27/65个文件:C:\Users\Li\python\抓娃娃.ipynb
# 正在转换第28/65个文件:C:\Users\Li\python\排序.ipynb
# 正在转换第29/65个文件:C:\Users\Li\python\整除10.ipynb
# 正在转换第30/65个文件:C:\Users\Li\python\斐波那契.ipynb
# 正在转换第31/65个文件:C:\Users\Li\python\期中.ipynb
# 正在转换第32/65个文件:C:\Users\Li\python\期末考试.ipynb
# 正在转换第33/65个文件:C:\Users\Li\python\格拉条的制作.ipynb
# 正在转换第34/65个文件:C:\Users\Li\python\模块封装.ipynb
# 正在转换第35/65个文件:C:\Users\Li\python\欢迎.ipynb
# 正在转换第36/65个文件:C:\Users\Li\python\正态分布计算.ipynb
# 正在转换第37/65个文件:C:\Users\Li\python\毛概.ipynb
# 正在转换第38/65个文件:C:\Users\Li\python\温标转换.ipynb
# 正在转换第39/65个文件:C:\Users\Li\python\爬虫.ipynb
# 正在转换第40/65个文件:C:\Users\Li\python\爬虫The_economist.ipynb
# 正在转换第41/65个文件:C:\Users\Li\python\猜数字.ipynb
# 正在转换第42/65个文件:C:\Users\Li\python\猴子摘桃.ipynb
# 正在转换第43/65个文件:C:\Users\Li\python\生成手写.ipynb
# 正在转换第44/65个文件:C:\Users\Li\python\生日相同概率.ipynb
# 正在转换第45/65个文件:C:\Users\Li\python\电话号码筛选.ipynb
# 正在转换第46/65个文件:C:\Users\Li\python\矩阵乘法.ipynb
# 正在转换第47/65个文件:C:\Users\Li\python\矩阵相加.ipynb
# 正在转换第48/65个文件:C:\Users\Li\python\矩阵转化.ipynb
# 正在转换第49/65个文件:C:\Users\Li\python\稀疏矩阵.ipynb
# 正在转换第50/65个文件:C:\Users\Li\python\第10周学习引导.ipynb
# 正在转换第51/65个文件:C:\Users\Li\python\第五周作业三.ipynb
# 正在转换第52/65个文件:C:\Users\Li\python\筛出长于10个字母的词.ipynb
# 正在转换第53/65个文件:C:\Users\Li\python\统计打印整数.ipynb
# 正在转换第54/65个文件:C:\Users\Li\python\统计收益率.ipynb
# 正在转换第55/65个文件:C:\Users\Li\python\统计汉字个数.ipynb
# 正在转换第56/65个文件:C:\Users\Li\python\自测题参考答案及点评（第一套）.ipynb
# 正在转换第57/65个文件:C:\Users\Li\python\自测题参考答案和点评（第二套）.ipynb
# 正在转换第58/65个文件:C:\Users\Li\python\行业资产负债率.ipynb
# 正在转换第59/65个文件:C:\Users\Li\python\解二元一次方程组.ipynb
# 正在转换第60/65个文件:C:\Users\Li\python\词云.ipynb
# 正在转换第61/65个文件:C:\Users\Li\python\身份证.ipynb
# 正在转换第62/65个文件:C:\Users\Li\python\递归.ipynb
# 正在转换第63/65个文件:C:\Users\Li\python\递归例题.ipynb
# 正在转换第64/65个文件:C:\Users\Li\python\随机数序列.ipynb
# 正在转换第65/65个文件:C:\Users\Li\python\验证码.ipynb
# 全部.ipynb文件转换完成！
